# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
import tensorflow as tf
from tensorflow_graph_in_jupyter import show_graph

# %% [markdown]
# ## Training a sequence classifier
#
# Note: the book uses `tensorflow.contrib.layers.fully_connected()` rather than `tf.layers.dense()` (which did not exist when this chapter was written). It is now preferable to use `tf.layers.dense()`, because anything in the contrib module may change or be deleted without notice. The `dense()` function is almost identical to the `fully_connected()` function. The main differences relevant to this chapter are:
# * several parameters are renamed: `scope` becomes `name`, `activation_fn` becomes `activation` (and similarly the `_fn` suffix is removed from other parameters such as `normalizer_fn`), `weights_initializer` becomes `kernel_initializer`, etc.
# * the default `activation` is now `None` rather than `tf.nn.relu`.

# %%
reset_graph()

n_steps = 28
n_inputs = 28
n_neurons = 150
n_outputs = 10

learning_rate = 0.001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

basic_cell = tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
outputs, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)

logits = tf.layers.dense(states, n_outputs)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                          logits=logits)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
X_test = mnist.test.images.reshape((-1, n_steps, n_inputs))
y_test = mnist.test.labels
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
n_epochs = 100
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            X_batch = X_batch.reshape((-1, n_steps, n_inputs))
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
# Out:
# 0 Train accuracy: 0.93333334 Test accuracy: 0.9311
# 1 Train accuracy: 0.96666664 Test accuracy: 0.9522
# 2 Train accuracy: 0.97333336 Test accuracy: 0.9583
# 3 Train accuracy: 0.96 Test accuracy: 0.966
# 4 Train accuracy: 0.97333336 Test accuracy: 0.9666
# 5 Train accuracy: 0.98 Test accuracy: 0.9722
# 6 Train accuracy: 0.98 Test accuracy: 0.9727
# 7 Train accuracy: 0.96666664 Test accuracy: 0.9714
# 8 Train accuracy: 0.96 Test accuracy: 0.9698
# 9 Train accuracy: 0.9866667 Test accuracy: 0.97
# 10 Train accuracy: 0.9866667 Test accuracy: 0.971
# 11 Train accuracy: 0.96666664 Test accuracy: 0.9721
# 12 Train accuracy: 0.98 Test accuracy: 0.9725
# 13 Train accuracy: 0.9866667 Test accuracy: 0.9765
# 14 Train accuracy: 0.96666664 Test accuracy: 0.9598
# 15 Train accuracy: 1.0 Test accuracy: 0.9736
# 16 Train accuracy: 0.99333334 Test accuracy: 0.9707
# 17 Train accuracy: 0.9866667 Test accuracy: 0.976
# 18 Train accuracy: 0.9866667 Test accuracy: 0.9767
# 19 Train accuracy: 0.98 Test accuracy: 0.9775
# 20 Train accuracy: 0.96666664 Test accuracy: 0.9766
# 21 Train accuracy: 0.96666664 Test accuracy: 0.9695
# 22 Train accuracy: 0.97333336 Test accuracy: 0.9756
# 23 Train accuracy: 0.99333334 Test accuracy: 0.9764
# 24 Train accuracy: 0.99333334 Test accuracy: 0.9744
# 25 Train accuracy: 1.0 Test accuracy: 0.9775
# 26 Train accuracy: 0.99333334 Test accuracy: 0.9761
# 27 Train accuracy: 0.9866667 Test accuracy: 0.9789
# 28 Train accuracy: 0.96666664 Test accuracy: 0.9796
# 29 Train accuracy: 0.99333334 Test accuracy: 0.9734
# 30 Train accuracy: 0.9866667 Test accuracy: 0.9766
# 31 Train accuracy: 1.0 Test accuracy: 0.9791
# 32 Train accuracy: 0.99333334 Test accuracy: 0.9788
# 33 Train accuracy: 1.0 Test accuracy: 0.9775
# 34 Train accuracy: 0.99333334 Test accuracy: 0.9803
# 35 Train accuracy: 1.0 Test accuracy: 0.9792
# 36 Train accuracy: 1.0 Test accuracy: 0.9814
# 37 Train accuracy: 0.99333334 Test accuracy: 0.9803
# 38 Train accuracy: 0.98 Test accuracy: 0.9762
# 39 Train accuracy: 1.0 Test accuracy: 0.979
# 40 Train accuracy: 0.9866667 Test accuracy: 0.9797
# 41 Train accuracy: 0.9866667 Test accuracy: 0.9796
